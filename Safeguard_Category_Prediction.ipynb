# %% [markdown]
# # Reading Dataset
# The dataset used here is from a gas refinery. The client is building several identical gas refineries. Therefore this data analysis and Machine Learning Algorithms are applicable for their future projects.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ("P Pretreatment PHA Safeguard Export.csv")
df
# Out:
#                                              Safeguard  \
# 0    1:106-300-LIT-060005-A/B/C close 106-300-UV-06...
# 1    2:106-300-LIT-060006-A/B/C close 106-300-UV-06...
# 2    3:106-300-LIT-060005 A/B/C closes 106-300-UV-0...
# 3    4:106-300-LIT-060005-A/B/C high level alarm wi...
# 4    5:106-300-LIT-060006-A/B/C closes UV 010001 on...
# ..                                                 ...
# 507  508:100% sized spare Hot Oil Filter 120-700-F-...
# 508  509:High differential pressure alarm at 120-70...
# 509  510:High differential pressure alarm at 120-70...
# 510  511:Low Temperature alarm from Hot Oil Furnace...
# 511                      512:LOPA-01-04: High evel SIF
#
#                            Tag                             Category  \
# 0     106-300-LIT-060005-A/B/C     Instrumented Protection Function
# 1    106-300-LIT-060006-A/B/C      Instrumented Protection Function
# 2     106-300-LIT-060005 A/B/C     Instrumented Protection Function
# 3     106-300-LIT-060005-A/B/C      Alarm and Operator Intervention
# 4     106-300-LIT-060006 A/B/C     Instrumented Protection Function
# ..                         ...                                  ...
# 507        120-700-F-20001-A/B  Redundant Backup Equipment / System
# 508       120-7000-PDAH-200016      Alarm and Operator Intervention
# 509        120-700-PDAH-200002      Alarm and Operator Intervention
# 510          120-700-TT-200101      Alarm and Operator Intervention
# 511                        NaN                                  NaN
#
#                               Location Used Is SIF  \
# 0                  1.1.9.1.1 \r\n1.1.9.3.1    True
# 1                  1.1.9.2.1 \r\n1.1.9.4.1    True
# 2                                1.1.8.1.1     NaN
# 3    1.1.8.1.2 \r\n1.1.8.1.3 \r\n1.1.8.1.4     NaN
# 4                                1.1.8.2.1     NaN
# ..                                      ...    ...
# 507                                     NaN    NaN
# 508                                     NaN    NaN
# 509                             1.53.1.2.1     NaN
# 510              1.55.1.1.1 \r\n1.55.1.3.1     NaN
# 511                                     NaN    NaN
#
#                                               Comments
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 507  Hot oil filter is not 100% spare for max CO2 c...
# 508                                                NaN
# 509                                                NaN
# 510  Note, there are interlocks in the Hot Oil Furn...
# 511                                                NaN
#
# [512 rows x 6 columns]

# %% [markdown]
# # Data cleaning
# * Step 1: Remove the number and colon in the Safeguard column and transform it into the "description" column
# * Step 2: Remove all blanks and outlier categories in "Category" column
#           We are only interested in interlocks, Alarms, equipment and check valves.
# * Step 3: Ordinal encoding the Categories
#           Interlocks can be either in the Safety Systems (Instrumented Protection function, which is also known as SIF) or Basic Process Control System (BPCS). The description of the interlocks are very similar. The difference is only in which system, safety system or BPCS, the interlocks are installed. Therefore, the algorithm will categorize them into a more encompassing category "Interlocks".

# %%
#Step 1:
description = []
for i, row in df.iterrows():
    temp = row['Safeguard'].split(':')[1:] #extract all the strings after the first colon
    description.append(" ".join(temp)) #concatentation of the descriptions
df['description'] = description #create new column "description"

#checking dataframe
df
# Out:
#                                              Safeguard  \
# 0    1:106-300-LIT-060005-A/B/C close 106-300-UV-06...
# 1    2:106-300-LIT-060006-A/B/C close 106-300-UV-06...
# 2    3:106-300-LIT-060005 A/B/C closes 106-300-UV-0...
# 3    4:106-300-LIT-060005-A/B/C high level alarm wi...
# 4    5:106-300-LIT-060006-A/B/C closes UV 010001 on...
# ..                                                 ...
# 507  508:100% sized spare Hot Oil Filter 120-700-F-...
# 508  509:High differential pressure alarm at 120-70...
# 509  510:High differential pressure alarm at 120-70...
# 510  511:Low Temperature alarm from Hot Oil Furnace...
# 511                      512:LOPA-01-04: High evel SIF
#
#                            Tag                             Category  \
# 0     106-300-LIT-060005-A/B/C     Instrumented Protection Function
# 1    106-300-LIT-060006-A/B/C      Instrumented Protection Function
# 2     106-300-LIT-060005 A/B/C     Instrumented Protection Function
# 3     106-300-LIT-060005-A/B/C      Alarm and Operator Intervention
# 4     106-300-LIT-060006 A/B/C     Instrumented Protection Function
# ..                         ...                                  ...
# 507        120-700-F-20001-A/B  Redundant Backup Equipment / System
# 508       120-7000-PDAH-200016      Alarm and Operator Intervention
# 509        120-700-PDAH-200002      Alarm and Operator Intervention
# 510          120-700-TT-200101      Alarm and Operator Intervention
# 511                        NaN                                  NaN
#
#                               Location Used Is SIF  \
# 0                  1.1.9.1.1 \r\n1.1.9.3.1    True
# 1                  1.1.9.2.1 \r\n1.1.9.4.1    True
# 2                                1.1.8.1.1     NaN
# 3    1.1.8.1.2 \r\n1.1.8.1.3 \r\n1.1.8.1.4     NaN
# 4                                1.1.8.2.1     NaN
# ..                                      ...    ...
# 507                                     NaN    NaN
# 508                                     NaN    NaN
# 509                             1.53.1.2.1     NaN
# 510              1.55.1.1.1 \r\n1.55.1.3.1     NaN
# 511                                     NaN    NaN
#
#                                               Comments  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 507  Hot oil filter is not 100% spare for max CO2 c...
# 508                                                NaN
# 509                                                NaN
# 510  Note, there are interlocks in the Hot Oil Furn...
# 511                                                NaN
#
#                                            description
# 0    106-300-LIT-060005-A/B/C close 106-300-UV-0600...
# 1    106-300-LIT-060006-A/B/C close 106-300-UV-0600...
# 2    106-300-LIT-060005 A/B/C closes 106-300-UV-010...
# 3    106-300-LIT-060005-A/B/C high level alarm with...
# 4    106-300-LIT-060006-A/B/C closes UV 010001 on h...
# ..                                                 ...
# 507  100% sized spare Hot Oil Filter 120-700-F-2000...
# 508  High differential pressure alarm at 120-7000-P...
# 509  High differential pressure alarm at 120-700-PD...
# 510  Low Temperature alarm from Hot Oil Furnace Dis...
# 511                          LOPA-01-04  High evel SIF
#
# [512 rows x 7 columns]

# %%
#Step 2:
df = df.dropna(subset=['Category']) # NOTE TO SELF df.dropna() by default returns a new dataset without NaN values. So, you have to assign it to the variable.
list = ['Instrumented Protection Function', 'Alarm and Operator Intervention', 'Redundant Backup Equipment / System', 'Basic Process Control System', 'Check Valve'] 
df = df[df['Category'].isin(list)]
#checking dataframe
df
# Out:
#                                              Safeguard  \
# 0    1:106-300-LIT-060005-A/B/C close 106-300-UV-06...
# 1    2:106-300-LIT-060006-A/B/C close 106-300-UV-06...
# 2    3:106-300-LIT-060005 A/B/C closes 106-300-UV-0...
# 3    4:106-300-LIT-060005-A/B/C high level alarm wi...
# 4    5:106-300-LIT-060006-A/B/C closes UV 010001 on...
# ..                                                 ...
# 506  507:Minimum Hot oil recycle flow through 120-7...
# 507  508:100% sized spare Hot Oil Filter 120-700-F-...
# 508  509:High differential pressure alarm at 120-70...
# 509  510:High differential pressure alarm at 120-70...
# 510  511:Low Temperature alarm from Hot Oil Furnace...
#
#                            Tag                             Category  \
# 0     106-300-LIT-060005-A/B/C     Instrumented Protection Function
# 1    106-300-LIT-060006-A/B/C      Instrumented Protection Function
# 2     106-300-LIT-060005 A/B/C     Instrumented Protection Function
# 3     106-300-LIT-060005-A/B/C      Alarm and Operator Intervention
# 4     106-300-LIT-060006 A/B/C     Instrumented Protection Function
# ..                         ...                                  ...
# 506         120-700-FV-200003          Basic Process Control System
# 507        120-700-F-20001-A/B  Redundant Backup Equipment / System
# 508       120-7000-PDAH-200016      Alarm and Operator Intervention
# 509        120-700-PDAH-200002      Alarm and Operator Intervention
# 510          120-700-TT-200101      Alarm and Operator Intervention
#
#                               Location Used Is SIF  \
# 0                  1.1.9.1.1 \r\n1.1.9.3.1    True
# 1                  1.1.9.2.1 \r\n1.1.9.4.1    True
# 2                                1.1.8.1.1     NaN
# 3    1.1.8.1.2 \r\n1.1.8.1.3 \r\n1.1.8.1.4     NaN
# 4                                1.1.8.2.1     NaN
# ..                                      ...    ...
# 506                                     NaN    NaN
# 507                                     NaN    NaN
# 508                                     NaN    NaN
# 509                             1.53.1.2.1     NaN
# 510              1.55.1.1.1 \r\n1.55.1.3.1     NaN
#
#                                               Comments  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 506                                                NaN
# 507  Hot oil filter is not 100% spare for max CO2 c...
# 508                                                NaN
# 509                                                NaN
# 510  Note, there are interlocks in the Hot Oil Furn...
#
#                                            description
# 0    106-300-LIT-060005-A/B/C close 106-300-UV-0600...
# 1    106-300-LIT-060006-A/B/C close 106-300-UV-0600...
# 2    106-300-LIT-060005 A/B/C closes 106-300-UV-010...
# 3    106-300-LIT-060005-A/B/C high level alarm with...
# 4    106-300-LIT-060006-A/B/C closes UV 010001 on h...
# ..                                                 ...
# 506  Minimum Hot oil recycle flow through 120-700-F...
# 507  100% sized spare Hot Oil Filter 120-700-F-2000...
# 508  High differential pressure alarm at 120-7000-P...
# 509  High differential pressure alarm at 120-700-PD...
# 510  Low Temperature alarm from Hot Oil Furnace Dis...
#
# [362 rows x 7 columns]

# %%
#Step 3:
#Changing SIFs and BPCS functions to 'Interlocks'
df['Category'] = df['Category'].replace(['Instrumented Protection Function', 'Basic Process Control System'], 'Interlocks') 
#Encoding Category column and create a new column Ordinal
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le_fitted = le.fit_transform(df['Category'])
df['Ordinal'] = le_fitted
#checking dataframe
df
# Out:
#                                              Safeguard  \
# 0    1:106-300-LIT-060005-A/B/C close 106-300-UV-06...
# 1    2:106-300-LIT-060006-A/B/C close 106-300-UV-06...
# 2    3:106-300-LIT-060005 A/B/C closes 106-300-UV-0...
# 3    4:106-300-LIT-060005-A/B/C high level alarm wi...
# 4    5:106-300-LIT-060006-A/B/C closes UV 010001 on...
# ..                                                 ...
# 506  507:Minimum Hot oil recycle flow through 120-7...
# 507  508:100% sized spare Hot Oil Filter 120-700-F-...
# 508  509:High differential pressure alarm at 120-70...
# 509  510:High differential pressure alarm at 120-70...
# 510  511:Low Temperature alarm from Hot Oil Furnace...
#
#                            Tag                             Category  \
# 0     106-300-LIT-060005-A/B/C                           Interlocks
# 1    106-300-LIT-060006-A/B/C                            Interlocks
# 2     106-300-LIT-060005 A/B/C                           Interlocks
# 3     106-300-LIT-060005-A/B/C      Alarm and Operator Intervention
# 4     106-300-LIT-060006 A/B/C                           Interlocks
# ..                         ...                                  ...
# 506         120-700-FV-200003                            Interlocks
# 507        120-700-F-20001-A/B  Redundant Backup Equipment / System
# 508       120-7000-PDAH-200016      Alarm and Operator Intervention
# 509        120-700-PDAH-200002      Alarm and Operator Intervention
# 510          120-700-TT-200101      Alarm and Operator Intervention
#
#                               Location Used Is SIF  \
# 0                  1.1.9.1.1 \r\n1.1.9.3.1    True
# 1                  1.1.9.2.1 \r\n1.1.9.4.1    True
# 2                                1.1.8.1.1     NaN
# 3    1.1.8.1.2 \r\n1.1.8.1.3 \r\n1.1.8.1.4     NaN
# 4                                1.1.8.2.1     NaN
# ..                                      ...    ...
# 506                                     NaN    NaN
# 507                                     NaN    NaN
# 508                                     NaN    NaN
# 509                             1.53.1.2.1     NaN
# 510              1.55.1.1.1 \r\n1.55.1.3.1     NaN
#
#                                               Comments  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 506                                                NaN
# 507  Hot oil filter is not 100% spare for max CO2 c...
# 508                                                NaN
# 509                                                NaN
# 510  Note, there are interlocks in the Hot Oil Furn...
#
#                                            description  Ordinal
# 0    106-300-LIT-060005-A/B/C close 106-300-UV-0600...        2
# 1    106-300-LIT-060006-A/B/C close 106-300-UV-0600...        2
# 2    106-300-LIT-060005 A/B/C closes 106-300-UV-010...        2
# 3    106-300-LIT-060005-A/B/C high level alarm with...        0
# 4    106-300-LIT-060006-A/B/C closes UV 010001 on h...        2
# ..                                                 ...      ...
# 506  Minimum Hot oil recycle flow through 120-700-F...        2
# 507  100% sized spare Hot Oil Filter 120-700-F-2000...        3
# 508  High differential pressure alarm at 120-7000-P...        0
# 509  High differential pressure alarm at 120-700-PD...        0
# 510  Low Temperature alarm from Hot Oil Furnace Dis...        0
#
# [362 rows x 8 columns]

# %% [markdown]
# # Splitting the dataframe into training and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.description, df.Ordinal, random_state = 42)

# %% [markdown]
# # Multinomial Naive Bayes Algorithm
#     This part of the code uses the pipeline API from the SKlearn Package

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

SafeguardCat = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
SafeguardCat.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
SafeguardCat.score(X_test,y_test)
# Out:
# 0.9120879120879121

# %% [markdown]
# # Testing with new data

# %%
test = ['high pressure across vessel', 'XXX trips pump']
result = SafeguardCat.predict(test)
print(le.inverse_transform(result)) #convert codes back to label
# Out:
# ['Alarm and Operator Intervention' 'Interlocks']

# %% [markdown]
# The result is very accurate based on real HAZOP records.
